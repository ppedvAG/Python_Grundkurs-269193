# %% [markdown]
# # IPython
#
# Interactive Python
#
# Mithilfe von Zellen, nur bestimmten Code ausführen, der auch benötigt wird
#
# - Element 1
# - Element 2
#
# __Fetter Text__
#
# ---

# %%
x = 5
x * 2
# Out:
# 10

# %%
import pandas as pd

# %%
pd.DataFrame({"Spalte 1": [1, 2, 3], "Spalte 2": [4, 5, 6], "Spalte 3": [7, 8, 9]})
# Out:
#    Spalte 1  Spalte 2  Spalte 3
# 0         1         4         7
# 1         2         5         8
# 2         3         6         9

# %%
import matplotlib.pyplot as plt  # WICHTIG: pyplot importieren

# %% [markdown]
# https://matplotlib.org/stable/plot_types/index.html

# %%
plt.plot([2.4, 1.1, 5.2, 4.9])
